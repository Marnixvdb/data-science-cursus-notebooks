# %% [markdown]
# # Decision Tree
#
# ## import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics
import pydotplus
from IPython.display import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## import dataset

# %%
dataset = load_breast_cancer()

X = pd.DataFrame(dataset.data)
X.columns = dataset.feature_names

y = dataset.target

display(X.head())
display(X.describe())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %% [markdown]
# ## Create Decision Tree

# %%
#split the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Fit the decision tree
model = tree.DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=42, max_leaf_nodes=None).fit(X_train, y_train)

#visualise the tree
tree.export_graphviz(model, out_file='tree.dot', feature_names=dataset.feature_names, 
                filled=True, rounded=True, special_characters=True)
# !dot -Tpng tree.dot -o tree.png -Gdpi=600 

Image(filename = 'tree.png')

# %% [markdown]
# ## Predictions and performance metrics

# %%
#Make predictions
prediction = model.predict(X_test)
probs = model.predict_proba(X_test)

#Only keep probabilities of the positive class
probs = probs[:, 1]

#get the false positive and true positive rates
fpr, tpr, thresholds = metrics.roc_curve(y_test, probs)
auc = metrics.roc_auc_score(y_test,probs)

plt.plot(fpr, tpr, color='navy', label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating curve')
plt.legend(loc="lower right")
plt.show()

confusion_matrix = metrics.confusion_matrix(y_test, prediction)
confusion_matrix = pd.DataFrame(confusion_matrix, columns=['class 0 pred','class 1 pred'], 
                                index=['class 0 true','class 1 true'])

print("confusion matrix:\n\n", confusion_matrix)
# Out:
# confusion matrix:
#
#                class 0 pred  class 1 pred
# class 0 true            56             7
# class 1 true             3           105
